# %%
import h5py
import numpy as np
from mayavi import mlab

# %%
f = h5py.File('visual.h5','r')

# %%
g = np.array(f['visual']['vis01'])

# %%
np.unique(g)
# Out:
# array([0.00000000e+00, 1.45794423e-04, 1.45794423e-04, 3.15994622e-04,
#        3.15994622e-04, 3.82055138e-04, 4.83663244e-04, 4.83663244e-04,
#        9.92097610e-04, 9.92097610e-04, 1.35076536e-03, 1.35076536e-03,
#        1.35076536e-03, 1.35076536e-03, 1.41238175e-03, 1.41238175e-03,
#        1.41238175e-03, 2.11032212e-03, 2.28615971e-03, 2.28615971e-03,
#        2.28615971e-03, 3.19233655e-03, 3.19233655e-03, 3.22222307e-03,
#        3.22222307e-03, 3.40044324e-03, 3.40044324e-03, 3.40044324e-03,
#        4.93395169e-03, 4.93395169e-03, 4.93395169e-03, 7.98052407e-03,
#        7.98052407e-03, 8.61919884e-03, 8.61919884e-03, 8.61919884e-03,
#        8.61919884e-03, 9.22105055e-03, 9.22105055e-03, 9.22105055e-03,
#        9.22105055e-03, 9.22105055e-03, 9.71625130e-03, 9.71625130e-03,
#        9.71625130e-03, 9.71625130e-03, 9.71625130e-03, 1.08154822e-02,
#        1.08154822e-02, 1.08154822e-02, 1.42664418e-02, 1.42664418e-02,
# ...

# %%
plt.contourf()
